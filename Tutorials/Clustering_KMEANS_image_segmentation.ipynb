# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorddickenstein/FSLRwithNLP/blob/main/Tutorials/Clustering_KMEANS_image_segmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from skimage.color import rgb2gray
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import ndimage

# %%
pic = plt.imread('/content/drive/MyDrive/Colab Notebooks/Images/1.jpeg')/255
print(f'Pic Shape: {pic.shape}')
plt.imshow(pic)
# Out:
# Pic Shape: (192, 263, 3)

# %%
# convert image to 2D (length*width, channels)
pic_n = pic.reshape(pic.shape[0]*pic.shape[1], pic.shape[2])
pic_n.shape
# Out:
# (50496, 3)

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=0).fit(pic_n)
pic2show = kmeans.cluster_centers_[kmeans.labels_]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-65e30a3c23f3> in <module>()
#       1 from sklearn.cluster import KMeans
# ----> 2 kmeans = KMeans(n_clusters=10, random_state=0).fit(pic_n)
#       3 pic2show = kmeans.cluster_centers_[kmeans.labels_]
#
# NameError: name 'pic_n' is not defined

# %%
cluster_pic = pic2show.reshape(pic.shape[0], pic.shape[1], pic.shape[2])
plt.imshow(cluster_pic)
